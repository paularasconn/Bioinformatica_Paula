# %% [markdown]
# # PRIMER NOTEBOOK
#
# **Este es mi primer notebook y voy a hacer lo siguiente.**
#
# Una lista enumerada:
# 1. Primero
# 2. Segundo
# 3. Tercero
#
# Una lista por puntos:
# - Primero
# - Segundo
# - Tercero
#
# Mi primer código:

# %%
mi_primera_frase = "Hello world"

# %%
# Para que se vea en la salida hay que usar print()
print(mi_primera_frase)
# Out:
# Hello world

# %%
# Lista de ejemplo
numeros = [10, 20, 30, 40, 50]

# %%
# Cálculo de la media usando operaciones básicas
media = sum(numeros) / len(numeros)

# %%
print(media)
# Out:
# 30.0

# %%
**finalizaremos con una bonita imagen**
![Mi imagen](imagen.png.png)
